# %%
import pandas as pd

# %%
usuarios = pd.read_excel('MATRIZ JANEIRO 2020 DIRCEU.xlsx')
bd = pd.read_excel('USUARIOS_DEZEMBRO.xlsx')

# %%
bd.set_index('matricula', inplace=True)
usuarios.set_index('matricula', inplace=True)

# %%
cidade = bd['cidade']

# %%
cidade = cidade.to_dict()

# %%
usuarios['cidade'] = usuarios.index.map(cidade)

# %%
usuarios
# Out:
#                                           nome   horario  Unnamed: 3  \
# matricula
# 146841       ANANDA MARIA LIMA MORAIS DA SILVA  06:10:00         NaN
# 125737              ANDREIA CARVALHO DE ARAUJO  06:10:00         NaN
# 154804                 EDUARDO LOBATO CARVALHO  06:10:00         NaN
# 166663             JACO FERREIRA CARVALHO LIMA  06:10:00         NaN
# 197861      MAX WENDEL PRADO ANTUNES DE AGUIAR  06:10:00         NaN
# ...                                        ...       ...         ...
# 220832                ROSICLEIA ALVES DA SILVA  23:00:00         NaN
# 222638      PEDRO MARCUS DE ASSIS FURTADO LIMA  00:00:00         NaN
# 238747             JOSIANE FRANCISCA DAS NEVES  23:30:00         NaN
# 222657        PLACIDO AUGUSTO QUEIROZ DA SILVA  00:30:00         NaN
# 140412     RAFAELA CRISTINA RODRIGUES DA SILVA  23:10:00         NaN
#
#                                        rua numero                    bairro  \
# matricula
# ...

# %%
usuarios.to_excel("cidade.xlsx")
