# %%
import pandas as pd

# %%
bd = pd.read_excel('USUARIOS_DEZEMBRO.xlsx')

# %%
enderecos = pd.read_excel('BD_Dezembro.xlsx')

# %%
enderecos.tail()
# Out:
#        SITE  MATRÍCULA                                    NOME  \
# 378  DIRCEU     221006             GERCIANE SALES DA CONCEICAO
# 379  DIRCEU     242004  MICHAELLY LAIANE CARVALHO DE O CRISPIM
# 380  DIRCEU     197536      WERICK ARAUJO RODRIGUES DOS SANTOS
# 381  DIRCEU     237778                  DAVID DE SOUSA PACHECO
# 382  DIRCEU     242121            LILYA LAYANE DA COSTA SOARES
#
#                       ENDEREÇO    Nº           BAIRRO   ZONA
# 378                QUADRA D 12    04   VALE DO GAVIAO  LESTE
# 379                   RUA ONZE    09  PORTO DO CENTRO  LESTE
# 380  CONJUNTO PLANALTO URUGUAI     9    VALE QUEM TEM  LESTE
# 381                   GOITACAZ  4151  VILA IRMA DULCE    SUL
# 382                         10  3080    SÃO SEBASTIÃO    SDB

# %%
endereco = enderecos[['MATRÍCULA','ENDEREÇO','Nº']]

# %%
pd.DataFrame(endereco)
# Out:
#      MATRÍCULA                   ENDEREÇO    Nº
# 0       247772        RUA EPITACIO PESSOA  1931
# 1       247704         RUA MARECHAL DUTRA  5902
# 2       229145                RUA COLOMBO  5415
# 3       228731     RUA ALBERTO LEAL NUNES  1778
# 4       222872                  QUADRA 34    10
# ..         ...                        ...   ...
# 378     221006                QUADRA D 12    04
# 379     242004                   RUA ONZE    09
# 380     197536  CONJUNTO PLANALTO URUGUAI     9
# 381     237778                   GOITACAZ  4151
# 382     242121                         10  3080
#
# [383 rows x 3 columns]

# %%
endereco.set_index('MATRÍCULA', inplace=True)

# %%
# endereco['ENDEREÇO'].str.cat(endereco['Nº'], sep =", ")
# endereco['endereco'] = endereco[['ENDEREÇO', 'Nº']].apply(lambda x: ' '.join(x), axis = 1)

# %%
endereco
# Out:
#                             ENDEREÇO    Nº
# MATRÍCULA
# 247772           RUA EPITACIO PESSOA  1931
# 247704            RUA MARECHAL DUTRA  5902
# 229145                   RUA COLOMBO  5415
# 228731        RUA ALBERTO LEAL NUNES  1778
# 222872                     QUADRA 34    10
# ...                              ...   ...
# 221006                   QUADRA D 12    04
# 242004                      RUA ONZE    09
# 197536     CONJUNTO PLANALTO URUGUAI     9
# 237778                      GOITACAZ  4151
# 242121                            10  3080
#
# [383 rows x 2 columns]

# %%
endereco['Nº'] = endereco['Nº'].astype(str).copy()
# Out:
# C:\Users\user\Anaconda3\envs\teste_vipi\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
endereco['endereco'] = endereco[['ENDEREÇO', 'Nº']].apply(lambda x: ', '.join(x), axis = 1)
# Out:
# C:\Users\user\Anaconda3\envs\teste_vipi\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
endereco = endereco['endereco']

# %%
endereço = endereco.to_dict()

# %%
teste = pd.read_excel('2019_12_24_rotas_horario_02.xlsx', sheet_name = 'dirceu_sul')

# %%
teste = teste.set_index(['matricula'])

# %%
teste = teste.drop(columns=['Unnamed: 0'])
teste
# Out:
#            filial                                  nome  \
# matricula
# 237672     DIRCEU               THALISON TIAGO DE SOUSA
# 225711     DIRCEU  LUCIA AMANDA MOEMA LORRANY S E SILVA
# 244135     DIRCEU             KATHLEEN COSTA MARTILIANO
# 237670     DIRCEU      ANDREIA MIKAELY DE SOUSA BARBOSA
# 197451     DIRCEU            MARIA MENDES DO NASCIMENTO
# 187465     DIRCEU           FRANCIEZIO SOARES FERNANDES
# 223319     DIRCEU            HELLEN RAQUEL MORAES MATOS
# 223309     DIRCEU        MARCOS VINICIUS RAMOS OLIVEIRA
# 225340     DIRCEU               NARA CERQUEIRA DA SILVA
# 225331     DIRCEU            SERGIO LUIS HIGINO CARDOSO
# 225714     DIRCEU             LUANN YURI ALVES DA SILVA
# 184278     DIRCEU      WANDERSON FELIPE CARDOSO E SILVA
#
#                                       rua numero            bairro zona  \
# matricula
# 237672                    QUADRA PROMORAR     24  RAIMUNDO PORTELA  SUL
# ...

# %%
teste['new_data_1'] = teste.index.map(endereço)

# %%
teste
# Out:
#            filial                                  nome  \
# matricula
# 237672     DIRCEU               THALISON TIAGO DE SOUSA
# 225711     DIRCEU  LUCIA AMANDA MOEMA LORRANY S E SILVA
# 244135     DIRCEU             KATHLEEN COSTA MARTILIANO
# 237670     DIRCEU      ANDREIA MIKAELY DE SOUSA BARBOSA
# 197451     DIRCEU            MARIA MENDES DO NASCIMENTO
# 187465     DIRCEU           FRANCIEZIO SOARES FERNANDES
# 223319     DIRCEU            HELLEN RAQUEL MORAES MATOS
# 223309     DIRCEU        MARCOS VINICIUS RAMOS OLIVEIRA
# 225340     DIRCEU               NARA CERQUEIRA DA SILVA
# 225331     DIRCEU            SERGIO LUIS HIGINO CARDOSO
# 225714     DIRCEU             LUANN YURI ALVES DA SILVA
# 184278     DIRCEU      WANDERSON FELIPE CARDOSO E SILVA
#
#                                       rua numero            bairro zona  \
# matricula
# 237672                    QUADRA PROMORAR     24  RAIMUNDO PORTELA  SUL
# ...
