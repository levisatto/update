# %%
import pandas as pd
import unittest
import viacep

# %%
aracaju = pd.read_excel('aracaju.xlsx')

# %%
aracaju.set_index('matricula')
# Out:
#                                       nome                           rua  \
# matricula
# 119244               ANA CLECIA DOS SANTOS      RUA MARIA DO CARMO SILVA
# 141390             JHONATAN MOTA RODRIGUES          AV DULCINEIA ALMEIDA
# 147828      BRENDA WILLIANE DE SOUZA SILVA    FRANCISCO CARDOSO DA SILVA
# 157479              MARIA JOSINA DE ARAUJO                RUA ALAN SILVA
# 159163              DANIELE ALMEIDA CAMPOS  RUA JOSE PEREIRA DE OLIVEIRA
# ...                                    ...                           ...
# 249780           MANRICK DE LACERDA SANTOS                  POCO DO MERO
# 249832           LOURIVAL OLIVEIRA MARQUES                     ANA CELIA
# 250019     ELISSON SOCORRO FONTES OLIVEIRA              RUA EDUARDO CRUZ
# 250024           LOYS LENE DE JESUS SANTOS                            17
# 250041         GLADSON FERREIRA DOS SANTOS                        F DOIS
#
#           numero             bairro       cep  cidade   horario  \
# matricula
# ...

# %%
import pycep_correios

# %%
def cidade(cep):
    try:
        endereco = pycep_correios.consultar_cep(cep)
        return endereco['cidade']
    except:
        return 'NaN'

# %%
cidade('49099999')
# Out:
# 'NaN'

# %%
cidades = []
for each in aracaju['cep']:
    cep = str(each)
    city = cidade(cep)
    print(city)
    cidades.append(city)
# Out:
# São Cristóvão
# São Cristóvão
# Aracaju
# São Cristóvão
# Aracaju
# São Cristóvão
# Aracaju
# São Cristóvão
# São Cristóvão
# São Cristóvão
# São Cristóvão
# São Cristóvão
# São Cristóvão
# São Cristóvão
# São Cristóvão
# São Cristóvão
# São Cristóvão
# Aracaju
# São Cristóvão
# São Cristóvão
# São Cristóvão
# Aracaju
# Aracaju
# Aracaju
# Aracaju
# Aracaju
# Nossa Senhora do Socorro
# Aracaju
# Nossa Senhora do Socorro
# Nossa Senhora do Socorro
# Aracaju
# Nossa Senhora do Socorro
# Nossa Senhora do Socorro
# Nossa Senhora do Socorro
# São Cristóvão
# Aracaju
# Nossa Senhora do Socorro
# Nossa Senhora do Socorro
# Aracaju
# Aracaju
# Aracaju
# Nossa Senhora do Socorro
# Nossa Senhora do Socorro
# Nossa Senhora do Socorro
# Nossa Senhora do Socorro
# NaN
# Nossa Senhora do Socorro
# Nossa Senhora do Socorro
# Aracaju
# Nossa Senhora do Socorro
# Nossa Senhora do Socorro
# Nossa Senhora do Socorro
# Nossa Senhora do Socorro
# Nossa Senhora do Socorro
# Nossa Senhora do Socorro
# ...

# %%
aracaju['cidade'] = cidades

# %%
aracaju.to_excel('aracaju_sep.xlsx')

# %%
aracaju = aracaju.set_index('matricula')

# %%
aracaju['numero'] = aracaju['numero'].astype(str).copy()

# %%
aracaju['rua'] = aracaju[['rua','numero' ]].apply(lambda x: ', '.join(x), axis = 1)

# %%
aracaju['bairro'] = aracaju[['bairro','cidade' ]].apply(lambda x: ', '.join(x), axis = 1)

# %%
aracaju['endereço'] = aracaju[['rua','bairro' ]].apply(lambda x: '- '.join(x), axis = 1)

# %%
aracaju['endereço']
# Out:
# matricula
# 119244    RUA MARIA DO CARMO SILVA, 0- ROSA ELZE, São Cr...
# 141390    AV DULCINEIA ALMEIDA, 310- ROSA ELZE, São Cris...
# 147828    FRANCISCO CARDOSO DA SILVA, 33- DEZOITO DO FOR...
# 157479        RUA ALAN SILVA, 221- ROSA ELZE, São Cristóvão
# 159163    RUA JOSE PEREIRA DE OLIVEIRA, 137- AMERICA, Ar...
#                                 ...
# 249780                    POCO DO MERO, 906- BUGIO, Aracaju
# 249832                        ANA CELIA, 29- BUGIO, Aracaju
# 250019           RUA EDUARDO CRUZ, 139- INDUSTRIAL, Aracaju
# 250024           17, 104- TAICOCA, Nossa Senhora do Socorro
# 250041                     F DOIS, 431- JARDIM CENTENARIO,
# Name: endereço, Length: 398, dtype: object

# %%
elim = ['rua', 'numero', 'bairro', 'cidade']
aracaju = aracaju.drop(columns=elim)

# %%
aracaju
# Out:
#                                       nome       cep   horario  \
# matricula
# 119244               ANA CLECIA DOS SANTOS  49100000  00:25:00
# 141390             JHONATAN MOTA RODRIGUES  49100000  00:25:00
# 147828      BRENDA WILLIANE DE SOUZA SILVA  49072216  00:25:00
# 157479              MARIA JOSINA DE ARAUJO  49100000  00:25:00
# 159163              DANIELE ALMEIDA CAMPOS  49080330  00:25:00
# ...                                    ...       ...       ...
# 249780           MANRICK DE LACERDA SANTOS  49090000  01:40:00
# 249832           LOURIVAL OLIVEIRA MARQUES  49090346  01:40:00
# 250019     ELISSON SOCORRO FONTES OLIVEIRA  49065330  01:40:00
# 250024           LOYS LENE DE JESUS SANTOS  49160000  01:40:00
# 250041         GLADSON FERREIRA DOS SANTOS  49000000  01:40:00
#
#                                 fretado  \
# matricula
# 119244     FRETADO - LINHA 03 B-Selo 22
# 141390     FRETADO - LINHA 03 B-Selo 22
# 147828     FRETADO - LINHA 03 B-Selo 22
# ...

# %%
aracaju.to_excel('aracaju_cidade.xlsx')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\Anaconda3\envs\teste_vipi\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     315             try:
# --> 316                 self._store_workbook()
#     317             except IOError as e:
#
# ~\Anaconda3\envs\teste_vipi\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     631         except IOError as e:
# --> 632             raise e
#     633
#
# ~\Anaconda3\envs\teste_vipi\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     629             xlsx_file = ZipFile(self.filename, "w", compression=ZIP_DEFLATED,
# --> 630                                 allowZip64=self.allow_zip64)
#     631         except IOError as e:
#
# ~\Anaconda3\envs\teste_vipi\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1206                 try:
# ...

# %%
import googlemaps
loc = 'RUA EDUARDO CRUZ, 139- INDUSTRIAL, Aracaju'
gmaps = googlemaps.Client(key='AIzaSyBn33MytAEJqHoHRS6CtzbHQd7XmQRo2hU')
geocode_result = gmaps.geocode(loc)
lat = geocode_result[0]["geometry"]["location"]["lat"]
lon = geocode_result[0]["geometry"]["location"]["lng"]

print(lat,lon)
